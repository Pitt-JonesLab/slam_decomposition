# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

import sys
sys.path.append("../../")

# %matplotlib widget

# %%
from src.basis import CircuitTemplate
basis = CircuitTemplate(preseed=True, use_polytopes=True)
basis.clear_all_save_data()
# Out:
# INFO:root:Saving data back to file

# %%
from src.cost_function import BasicCost
objective = BasicCost()

# %%
from src.optimizer import TemplateOptimizer
optimizer = TemplateOptimizer(basis=basis, objective=objective, use_callback=True)

# %%
from src.sampler import HaarSample as HaarSample #Haar3Sample
sampler = HaarSample(n_samples=10, seed=None)
ret = optimizer.approximate_from_distribution(sampler=sampler)
# Out:
# INFO:root:Starting sample iter 0
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.44145673, 0.15997519, 0.01065241)
# INFO:root:Begin search: (0.4338411, 0.17068629, 0.05334486)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=7.375722255176242e-11
# INFO:root:Success: (0.4338411, 0.17068629, 0.05334486)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 1
# INFO:root:Monodromy found needs 3 basis applications
# INFO:root:Begin search: (0.5333144, 0.31484177, 0.15409169)
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=1.3570000678697625e-10
# INFO:root:Success: (0.5333144, 0.31484177, 0.15409169)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 2
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Begin search: (0.50417529, 0.34629197, 0.00036783)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=9.283700475037904e-10
# INFO:root:Success: (0.50417529, 0.34629197, 0.00036783)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 3
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.61624324, 0.21539235, 0.09855552)
# INFO:root:Begin search: (0.6620779, 0.20278652, 0.10750052)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=3.3238722885187144e-10
# INFO:root:Success: (0.6620779, 0.20278652, 0.10750052)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 4
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.50417529, 0.34629197, 0.00036783)
# INFO:root:Begin search: (0.43655147, 0.30022475, 0.02326893)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=2.318749636742723e-10
# INFO:root:Success: (0.43655147, 0.30022475, 0.02326893)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 5
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.6620779, 0.20278652, 0.10750052)
# INFO:root:Begin search: (0.75175515, 0.16062005, 0.00422061)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=3.9041481159074465e-10
# INFO:root:Success: (0.75175515, 0.16062005, 0.00422061)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 6
# INFO:root:Monodromy found needs 3 basis applications
# INFO:root:Preseed from neighbor: (0.6630694, 0.25681861, 0.08728637)
# INFO:root:Begin search: (0.63412531, 0.26564129, 0.15809986)
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=6.158275001055813e-10
# INFO:root:Success: (0.63412531, 0.26564129, 0.15809986)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 7
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.56249914, 0.31114924, 0.08929752)
# INFO:root:Begin search: (0.53183567, 0.29156986, 0.07119795)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=1.0301581809812888e-10
# INFO:root:Success: (0.53183567, 0.29156986, 0.07119795)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 8
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.61624324, 0.21539235, 0.09855552)
# INFO:root:Begin search: (0.56424517, 0.21708574, 0.12212497)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=4.3194203769303385e-10
# INFO:root:Success: (0.56424517, 0.21708574, 0.12212497)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 9
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.49564791, 0.25998416, 0.0819941)
# INFO:root:Begin search: (0.52402984, 0.26223899, 0.11590971)
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=5.958855631149618e-11
# INFO:root:Success: (0.52402984, 0.26223899, 0.11590971)
# INFO:root:Saving data back to file

# %%
from src.utils.visualize import optimizer_training_plot
optimizer_training_plot(*ret);

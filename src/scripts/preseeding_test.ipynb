# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

import sys
sys.path.append("../../")

# %matplotlib widget

# %%
from src.basis import CircuitTemplate
basis = CircuitTemplate(preseed=True, use_polytopes=True)
basis.clear_all_save_data()
# Out:
# INFO:root:Saving data back to file

# %%
from src.cost_function import BasicCost
objective = BasicCost()

# %%
from src.optimizer import TemplateOptimizer
optimizer = TemplateOptimizer(basis=basis, objective=objective, use_callback=True)

# %%
from src.sampler import HaarSample as HaarSample #Haar3Sample
sampler = HaarSample(n_samples=5)
ret = optimizer.approximate_from_distribution(sampler=sampler)
# Out:
# INFO:root:Starting sample iter 0
# INFO:root:Begin search: (0.45639044, 0.29440687, 0.06684787)
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=4.6023440614106903e-10
# INFO:root:Success: (0.45639044, 0.29440687, 0.06684787)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 1
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Preseed from neighbor: (0.45639044, 0.29440687, 0.06684787)
# INFO:root:Begin search: (0.40319978, 0.20906541, 0.07467783)
# INFO:root:Monodromy found needs 2 basis applications
# INFO:root:Starting opt on template size 2
# INFO:root:Break on cycle 2
# INFO:root:Loss=1.66049174410432e-10
# INFO:root:Success: (0.40319978, 0.20906541, 0.07467783)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 2
# INFO:root:Monodromy found needs 3 basis applications
# INFO:root:Begin search: (0.56899562, 0.39736965, 0.10817599)
# INFO:root:Monodromy found needs 3 basis applications
# INFO:root:Starting opt on template size 3
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py:459, in ParameterExpression.__float__(self)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=457'>458</a> try:
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=458'>459</a>     return float(self._symbol_expr)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=459'>460</a> # TypeError is for sympy, RuntimeError for symengine
#
# File symengine_wrapper.pyx:1151, in symengine.lib.symengine_wrapper.Basic.__float__()
#
# File symengine_wrapper.pyx:976, in symengine.lib.symengine_wrapper.Basic.n()
#
# File symengine_wrapper.pyx:4346, in symengine.lib.symengine_wrapper.evalf()
#
# RuntimeError: Symbol cannot be evaluated.
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /home/evm9/decomposition_EM/src/scripts/preseeding_test.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/preseeding_test.ipynb#ch0000004vscode-remote?line=0'>1</a> from src.sampler import HaarSample as HaarSample #Haar3Sample
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/preseeding_test.ipynb#ch0000004vscode-remote?line=1'>2</a> sampler = HaarSample(n_samples=5)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/preseeding_test.ipynb#ch0000004vscode-remote?line=2'>3</a> ret = optimizer.approximate_from_distribution(sampler=sampler)
#
# File ~/decomposition_EM/src/scripts/../../src/optimizer.py:83, in TemplateOptimizer.approximate_from_distribution(self, sampler)
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=80'>81</a> for target in sampler:
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=81'>82</a>     logging.info(f"Starting sample iter {self.sample_iter}")
# ---> <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=82'>83</a>     self.approximate_target_U(target_U=target)
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=83'>84</a>     self.sample_iter += 1
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=84'>85</a> return self.training_loss, self.coordinate_list
#
# File ~/decomposition_EM/src/scripts/../../src/optimizer.py:55, in TemplateOptimizer.approximate_target_U(self, target_U)
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=51'>52</a>             self.basis.assign_seed(found_saved.Xk)
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=53'>54</a> logging.info(f"Begin search: {target_coordinates}")
# ---> <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=54'>55</a> best_result, best_Xk, best_cycles = self.run(target_U)
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=56'>57</a> if best_result <= SUCCESS_THRESHOLD:
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=57'>58</a>     # label target coordinate as success
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=58'>59</a>     success_label = 1
#
# File ~/decomposition_EM/src/scripts/../../src/optimizer.py:123, in TemplateOptimizer.run(self, target_u)
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=117'>118</a> #TODO if spanning range == 1, don't pass to optimizer
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=118'>119</a> #implement a mathematica cloud call?
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=120'>121</a> for _ in range(TRAINING_RESTARTS):
# --> <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=122'>123</a>     result = opt.minimize(
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=123'>124</a>         fun=objective_func,
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=124'>125</a>         method='BFGS',
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=125'>126</a>         x0=self.basis.paramter_guess(),
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=126'>127</a>         callback=callbackF if self.use_callback else None,
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=127'>128</a>         options={"maxiter": 200},
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=128'>129</a>     )
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=130'>131</a>     # result is good, update temp vars
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=131'>132</a>     if best_result is None or result.fun < best_result:
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py:687, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py?line=684'>685</a>     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py?line=685'>686</a> elif meth == 'bfgs':
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py?line=686'>687</a>     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py?line=687'>688</a> elif meth == 'newton-cg':
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py?line=688'>689</a>     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py?line=689'>690</a>                              **options)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py:1296, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=1292'>1293</a> if maxiter is None:
#    <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=1293'>1294</a>     maxiter = len(x0) * 200
# -> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=1295'>1296</a> sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=1296'>1297</a>                               finite_diff_rel_step=finite_diff_rel_step)
#    <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=1298'>1299</a> f = sf.fun
#    <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=1299'>1300</a> myfprime = sf.grad
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py:263, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=258'>259</a>     bounds = (-np.inf, np.inf)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=260'>261</a> # ScalarFunction caches. Reuse of fun(x) during grad
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=261'>262</a> # calculation reduces overall function evaluations.
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=262'>263</a> sf = ScalarFunction(fun, x0, args, grad, hess,
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=263'>264</a>                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py?line=265'>266</a> return sf
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=154'>155</a>     self.f = fun_wrapped(self.x)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=156'>157</a> self._update_fun_impl = update_fun
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=157'>158</a> self._update_fun()
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=159'>160</a> # Gradient evaluation
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=160'>161</a> if callable(grad):
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=248'>249</a> def _update_fun(self):
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=249'>250</a>     if not self.f_updated:
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=250'>251</a>         self._update_fun_impl()
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=251'>252</a>         self.f_updated = True
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=153'>154</a> def update_fun():
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=154'>155</a>     self.f = fun_wrapped(self.x)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=132'>133</a> self.nfev += 1
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=133'>134</a> # Send a copy because the user may overwrite it.
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=134'>135</a> # Overwriting results in undefined behaviour because
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=135'>136</a> # fun(self.x) will change self.x, with the two no longer linked.
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=136'>137</a> fx = fun(np.copy(x), *args)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=137'>138</a> # Make sure the function returns a true scalar
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py?line=138'>139</a> if not np.isscalar(fx):
#
# File ~/decomposition_EM/src/scripts/../../src/optimizer.py:90, in TemplateOptimizer.run.<locals>.objective_func(xk)
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=88'>89</a> def objective_func(xk):
# ---> <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=89'>90</a>     current_u = self.basis.eval(xk)
#      <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/optimizer.py?line=90'>91</a>     return self.objective.unitary_fidelity(current_u, target_u)
#
# File ~/decomposition_EM/src/scripts/../../src/basis.py:144, in CircuitTemplate.eval(self, Xk)
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/basis.py?line=141'>142</a> def eval(self, Xk):
#     <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/basis.py?line=142'>143</a>     """returns an Operator after binding parameter array to template"""
# --> <a href='file:///home/evm9/decomposition_EM/src/scripts/../../src/basis.py?line=143'>144</a>     return Operator(self.assign_Xk(Xk)).data
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:86, in Operator.__init__(self, data, input_dims, output_dims)
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=76'>77</a>     self._data = np.asarray(data, dtype=complex)
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=77'>78</a> elif isinstance(data, (QuantumCircuit, Instruction)):
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=78'>79</a>     # If the input is a Terra QuantumCircuit or Instruction we
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=79'>80</a>     # perform a simulation to construct the unitary operator.
#    (...)
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=83'>84</a>     # conditional gates, measure, or reset will cause an
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=84'>85</a>     # exception to be raised.
# ---> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=85'>86</a>     self._data = self._init_instruction(data).data
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=86'>87</a> elif hasattr(data, "to_operator"):
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=87'>88</a>     # If the data object has a 'to_operator' attribute this is given
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=88'>89</a>     # higher preference than the 'to_matrix' method for initializing
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=89'>90</a>     # an Operator object.
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=90'>91</a>     data = data.to_operator()
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:511, in Operator._init_instruction(cls, instruction)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=508'>509</a> if isinstance(instruction, QuantumCircuit):
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=509'>510</a>     instruction = instruction.to_instruction()
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=510'>511</a> op._append_instruction(instruction)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=511'>512</a> return op
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:579, in Operator._append_instruction(self, obj, qargs)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=576'>577</a> else:
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=577'>578</a>     new_qargs = [qargs[bit_indices[tup]] for tup in qregs]
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=578'>579</a> self._append_instruction(instr, qargs=new_qargs)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:534, in Operator._append_instruction(self, obj, qargs)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=530'>531</a> from qiskit.circuit.barrier import Barrier
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=531'>532</a> from .scalar_op import ScalarOp
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=533'>534</a> mat = self._instruction_to_matrix(obj)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=534'>535</a> if mat is not None:
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=535'>536</a>     # Perform the composition and inplace update the current state
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=536'>537</a>     # of the operator
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=537'>538</a>     op = self.compose(mat, qargs=qargs)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:524, in Operator._instruction_to_matrix(cls, obj)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=519'>520</a> if hasattr(obj, "to_matrix"):
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=520'>521</a>     # If instruction is a gate first we see if it has a
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=521'>522</a>     # `to_matrix` definition and if so use that.
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=522'>523</a>     try:
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=523'>524</a>         mat = obj.to_matrix()
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=524'>525</a>     except QiskitError:
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py?line=525'>526</a>         pass
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py:55, in Gate.to_matrix(self)
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=43'>44</a> """Return a Numpy.array for the gate unitary matrix.
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=44'>45</a>
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=45'>46</a> Returns:
#    (...)
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=50'>51</a>         exception will be raised when this base class method is called.
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=51'>52</a> """
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=52'>53</a> if hasattr(self, "__array__"):
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=53'>54</a>     # pylint: disable=no-member
# ---> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=54'>55</a>     return self.__array__(dtype=complex)
#      <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py?line=55'>56</a> raise CircuitError(f"to_matrix not defined for this {type(self)}")
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py:119, in UGate.__array__(self, dtype)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=116'>117</a> def __array__(self, dtype=None):
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=117'>118</a>     """Return a numpy.array for the U gate."""
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=118'>119</a>     theta, phi, lam = (float(param) for param in self.params)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=119'>120</a>     return numpy.array(
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=120'>121</a>         [
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=121'>122</a>             [numpy.cos(theta / 2), -numpy.exp(1j * lam) * numpy.sin(theta / 2)],
#    (...)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=127'>128</a>         dtype=dtype,
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=128'>129</a>     )
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py:119, in <genexpr>(.0)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=116'>117</a> def __array__(self, dtype=None):
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=117'>118</a>     """Return a numpy.array for the U gate."""
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=118'>119</a>     theta, phi, lam = (float(param) for param in self.params)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=119'>120</a>     return numpy.array(
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=120'>121</a>         [
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=121'>122</a>             [numpy.cos(theta / 2), -numpy.exp(1j * lam) * numpy.sin(theta / 2)],
#    (...)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=127'>128</a>         dtype=dtype,
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/library/standard_gates/u.py?line=128'>129</a>     )
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py:462, in ParameterExpression.__float__(self)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=459'>460</a> # TypeError is for sympy, RuntimeError for symengine
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=460'>461</a> except (TypeError, RuntimeError) as exc:
# --> <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=461'>462</a>     raise TypeError(
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=462'>463</a>         "ParameterExpression with unbound parameters ({}) "
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=463'>464</a>         "cannot be cast to a float.".format(self.parameters)
#     <a href='file:///home/evm9/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/parameterexpression.py?line=464'>465</a>     ) from exc
#
# TypeError: ParameterExpression with unbound parameters ({Parameter(P4)}) cannot be cast to a float.

# %%
from src.utils.visualize import optimizer_training_plot
optimizer_training_plot(*ret);

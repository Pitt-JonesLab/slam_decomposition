# %%
# this notebook wants to use our cost function to find best SWAP that lines at points between B and sqswap
# the gates on this line can build SWAP in 2 cases (homogenous basis)
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %matplotlib widget

import sys
sys.path.append("../../../")
import numpy as np

# %%
from weylchamber import c1c2c3
from qiskit import QuantumCircuit
from src.utils.custom_gates import RiSwapGate
from qiskit.quantum_info import Operator

# %%
from src.basisv2 import CircuitTemplateV2
from src.utils.custom_gates import ConversionGainSmushGate
basis = CircuitTemplateV2(n_qubits=2, base_gates = [RiSwapGate], edge_params=[[(0,1)]])

duration_1q = 0.25
varg_offset = 2 #set to 4 if want to use phase, and change 0s to vargs in pp2 constructor below
t= 1.0
pp2 =lambda *vargs: ConversionGainSmushGate(0,0 , vargs[0], vargs[1], vargs[varg_offset:varg_offset+round(t/duration_1q)], vargs[varg_offset+round(t/duration_1q):], t_el=t)
basis = CircuitTemplateV2(n_qubits=2, base_gates = [pp2], edge_params=[[(0,1)]], vz_only=True, param_vec_expand=[varg_offset,round(t/duration_1q),round(t/duration_1q)])
basis_str = "CG2Q"


basis.build(2)
basis.spanning_range = range(2,3)

#for all smush gates make bounds
bounds_1q = 4*np.pi
for el in basis.circuit.parameters:
    s_el = str(el)
    if 'Q' in s_el:
        basis.add_bound(s_el, bounds_1q, -bounds_1q)

# manually set the gc, gg bounds
for el in basis.circuit.parameters:
    s_el = str(el)
    if s_el in ["Q0", "Q1", "Q22", "Q23", "Q44", "Q45"]:
        basis.add_bound(s_el, 0.5*np.pi, 0) #XXX when using riswapgate should be 0.5, but when using ConversionGain should be np.pi/2 !!! BAD BAD BAD


from src.sampler import HaarSample, GateSample
from qiskit.circuit.library import CXGate, CZGate, SwapGate
sampler = GateSample(gate = SwapGate())
s = [s for s in sampler][0]

from src.optimizer import TemplateOptimizer
from src.cost_function import BasicCostInverse, BasicCost, BsqSwapCost
objective1 = BasicCost()
objective2 = BsqSwapCost()
optimizer3 = TemplateOptimizer(basis=basis, objective=objective2, use_callback=True, override_fail=True, success_threshold = 1e-7, training_restarts=1)

# %%
ret3 = optimizer3.approximate_from_distribution(sampler) #get coordinate list
# Out:
# INFO:root:Starting sample iter 0
# INFO:root:Begin search: (0.5, 0.5, 0.5)
# INFO:root:Starting opt on template size 2
# 100%|██████████| 1/1 [02:17<00:00, 137.92s/it]
# INFO:root:Cycle (k =2), Best Loss=2.3579652245345712e-07
# INFO:root:Overall Best Loss=2.3579652245345712e-07
# INFO:root:Fail: (0.5, 0.5, 0.5), Found: (0.54565485, 0.25000022, 0.04565473)

# %%
from src.utils.visualize import optimizer_training_plot
optimizer_training_plot(ret3[0], ret3[1]);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Next, we want to use our binary search constraining circuit cost to find lower the circuit cost where it meets the SWAP-pair line

# %%
# Here we want to save the best cost as a function of the success threshold
# success_thresholds = [0.99, 0.999, 0.9999, 0.99999, 0.999999]
# fidelities = [None]*len(success_thresholds)
# for k, success_threshold in enumerate(success_thresholds):
#     objective1 = BasicCost()
    
# keep trying until success_threshold converges:
i=0
LB = .5
UB = 1.5
current_cost = (UB + LB)/2

# keep trying until success_threshold converges:
while i == 0 or np.abs(current_cost - previous_cost) > 0.01:
    if not current_cost is None:
        basis.set_constraint(param_max_cost=current_cost)
        #pass
    #rebuild optimizer to refresh the updated f_basis obj
    #NOTE setting the success threshold low since SWAP is very hard to find exactly
    optimizer3 = TemplateOptimizer(basis=basis, objective=objective2, use_callback=True, override_fail=True, success_threshold = 1e-7, training_restarts=5)

    _ret3 = optimizer3.approximate_target_U(s)
    current_cost = basis.circuit_cost(_ret3.Xk)
    print(f"Iteration:{i}, Decomposition Result:{_ret3.loss_result}, Cost:{current_cost},")

    #search using 2 steps forward, 1 step back approach BAD
    # I want to do a binary search between 0 and 1.5 
    # if success, then set next cost to be current - LB / 2
    # if fail, then set next cost to be current + (UB - current) / 2
    
    if _ret3.success_label:
        ret3 = _ret3
        #fidelities[k] = ret3

        #success means can tighten the constraint
        previous_cost = current_cost
        current_cost = (current_cost - LB)/2
        print("Success, new cost:", current_cost)
        #update UB
        UB = previous_cost

    else:
        #fail means loosen the constraint
        previous_cost = current_cost
        current_cost = current_cost + (UB - current_cost)/2
        print("Fail, new cost:", current_cost)
        #update LB
        LB = previous_cost

    i+=1

    # # save fidelities to h5 file
    # with h5py.File(f'swap_fidelities_{basis_str}.h5', 'a') as hf:
    #     #if dataset exists, delete it
    #     if f"success_{success_threshold}" in hf:
    #         del hf[f"success_{success_threshold}"]
    #     hf.create_dataset(f"success_{success_threshold}", data=fidelities[k])
# Out:
# INFO:root:Begin search: (0.5, 0.5, 0.5)
# INFO:root:Starting opt on template size 2
# 100%|██████████| 5/5 [00:31<00:00,  6.33s/it]
# INFO:root:Cycle (k =2), Best Loss=0.07134003066245626
# INFO:root:Overall Best Loss=0.07134003066245626
# INFO:root:Fail: (0.5, 0.5, 0.5), Found: (0.60826009, 0.1871298, 0.06057911)
# INFO:root:Begin search: (0.5, 0.5, 0.5)
# INFO:root:Starting opt on template size 2
# Iteration:0, Decomposition Result:0.07134003066245626, Cost:1.000000002775425,
# Fail, new cost: 1.2500000013877126
# 100%|██████████| 5/5 [00:35<00:00,  7.10s/it]
# INFO:root:Cycle (k =2), Best Loss=0.03104270931302389
# INFO:root:Overall Best Loss=0.03104270931302389
# INFO:root:Fail: (0.5, 0.5, 0.5), Found: (0.5894306, 0.28040439, 0.09828756)
# INFO:root:Begin search: (0.5, 0.5, 0.5)
# INFO:root:Starting opt on template size 2
# Iteration:1, Decomposition Result:0.03104270931302389, Cost:1.249999997385549,
# Fail, new cost: 1.3749999986927746
# 100%|██████████| 5/5 [00:38<00:00,  7.73s/it]
# INFO:root:Cycle (k =2), Best Loss=0.043493543363622385
# INFO:root:Overall Best Loss=0.043493543363622385
# INFO:root:Fail: (0.5, 0.5, 0.5), Found: (0.63916096, 0.20824779, 0.12193068)
# INFO:root:Begin search: (0.5, 0.5, 0.5)
# INFO:root:Starting opt on template size 2
# Iteration:2, Decomposition Result:0.043493543363622385, Cost:1.3749999986924764,
# Fail, new cost: 1.437499999346238
#  20%|██        | 1/5 [00:17<01:10, 17.54s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb Cell 7 in <cell line: 14>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     #pass
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> #rebuild optimizer to refresh the updated f_basis obj
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> #NOTE setting the success threshold low since SWAP is very hard to find exactly
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> optimizer3 = TemplateOptimizer(basis=basis, objective=objective2, use_callback=True, override_fail=True, success_threshold = 1e-7, training_restarts=5)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> _ret3 = optimizer3.approximate_target_U(s)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> current_cost = basis.circuit_cost(_ret3.Xk)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a> print(f"Iteration:{i}, Decomposition Result:{_ret3.loss_result}, Cost:{current_cost},")
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/optimizer.py:60, in TemplateOptimizer.approximate_target_U(self, target_U)
#      57     target_spanning_range = init_run_results
#      59 logging.info(f"Begin search: {target_coordinates}")
# ---> 60 best_result, best_Xk, best_cycles = self._run(target_U, target_spanning_range)
#      62 if best_result <= self.success_threshold:
#      63     # label target coordinate as success
#      64     success_label = 1
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/optimizer.py:227, in TemplateOptimizer._run(self, target_u, target_spanning_range)
#     220 if self.basis.using_constraints:
#     221     #method_str = "COBYLA"
#     222     # #NOTE cobyla does not support bounds
#     223     #this is probably fine, but we need to convert the bounds to constraints
#     224     #just use SLSQP instead
#     225     method_str = "SLSQP"
# --> 227 result = opt.minimize(
#     228     fun=objective_func,
#     229     method=method_str,
#     230     x0=self.basis.parameter_guess(t=r_i),
#     231     callback=callbackF if self.use_callback else None,
#     232     options={"maxiter": 2500},
#     233     bounds=self.basis.bounds_list, #grab bounds list
#     234     constraints=self.basis.constraint_func #grab constraint function
#     235 )
#     237 # result is good, update temp vars
#     238 if best_result is None or result.fun < best_result:
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     699                             **options)
#     700 elif meth == 'slsqp':
# --> 701     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     702                           constraints, callback=callback, **options)
#     703 elif meth == 'trust-constr':
#     704     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     705                                        bounds, constraints,
#     706                                        callback=callback, **options)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_slsqp_py.py:428, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     422 slsqp(m, meq, x, xl, xu, fx, c, g, a, acc, majiter, mode, w, jw,
#     423       alpha, f0, gs, h1, h2, h3, h4, t, t0, tol,
#     424       iexact, incons, ireset, itermx, line,
#     425       n1, n2, n3)
#     427 if mode == 1:  # objective and constraint evaluation required
# --> 428     fx = wrapped_fun(x)
#     429     c = _eval_constraint(x, cons)
#     431 if mode == -1:  # gradient evaluation required
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py:277, in _clip_x_for_func.<locals>.eval(x)
#     275 def eval(x):
#     276     x = _check_clip_x(x, bounds)
# --> 277     return func(x)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction.fun(self, x)
#     265 if not np.array_equal(x, self.x):
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 return self.f
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/optimizer.py:175, in TemplateOptimizer._run.<locals>.objective_func(xk)
#     173 elif isinstance(self.objective, LineSegmentDistanceCost):
#     174     current_qc = self.basis.assign_Xk(xk)
# --> 175     objf_val = self.objective.distance(current_qc)
#     176 else:
#     177     raise ValueError("Unrecognized Cost Function")
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/cost_function.py:24, in LineSegmentDistanceCost.distance(self, qc)
#      23 def distance(self, qc):
# ---> 24     c = c1c2c3(Operator(qc).data)
#      25     # return distance from c to the line segment
#      26     return np.linalg.norm(np.cross(self.line_segment[1]-self.line_segment[0], self.line_segment[0]-c)) / np.linalg.norm(self.line_segment[1]-self.line_segment[0])
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:86, in Operator.__init__(self, data, input_dims, output_dims)
#      77     self._data = np.asarray(data, dtype=complex)
#      78 elif isinstance(data, (QuantumCircuit, Instruction)):
#      79     # If the input is a Terra QuantumCircuit or Instruction we
#      80     # perform a simulation to construct the unitary operator.
#    (...)
#      84     # conditional gates, measure, or reset will cause an
#      85     # exception to be raised.
# ---> 86     self._data = self._init_instruction(data).data
#      87 elif hasattr(data, "to_operator"):
#      88     # If the data object has a 'to_operator' attribute this is given
#      89     # higher preference than the 'to_matrix' method for initializing
#      90     # an Operator object.
#      91     data = data.to_operator()
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:511, in Operator._init_instruction(cls, instruction)
#     509 if isinstance(instruction, QuantumCircuit):
#     510     instruction = instruction.to_instruction()
# --> 511 op._append_instruction(instruction)
#     512 return op
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:579, in Operator._append_instruction(self, obj, qargs)
#     577 else:
#     578     new_qargs = [qargs[bit_indices[tup]] for tup in qregs]
# --> 579 self._append_instruction(instr, qargs=new_qargs)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:534, in Operator._append_instruction(self, obj, qargs)
#     531 from qiskit.circuit.barrier import Barrier
#     532 from .scalar_op import ScalarOp
# --> 534 mat = self._instruction_to_matrix(obj)
#     535 if mat is not None:
#     536     # Perform the composition and inplace update the current state
#     537     # of the operator
#     538     op = self.compose(mat, qargs=qargs)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/quantum_info/operators/operator.py:524, in Operator._instruction_to_matrix(cls, obj)
#     520 if hasattr(obj, "to_matrix"):
#     521     # If instruction is a gate first we see if it has a
#     522     # `to_matrix` definition and if so use that.
#     523     try:
# --> 524         mat = obj.to_matrix()
#     525     except QiskitError:
#     526         pass
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qiskit/circuit/gate.py:55, in Gate.to_matrix(self)
#      44 """Return a Numpy.array for the gate unitary matrix.
#      45
#      46 Returns:
#    (...)
#      51         exception will be raised when this base class method is called.
#      52 """
#      53 if hasattr(self, "__array__"):
#      54     # pylint: disable=no-member
# ---> 55     return self.__array__(dtype=complex)
#      56 raise CircuitError(f"to_matrix not defined for this {type(self)}")
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/utils/custom_gates.py:147, in ConversionGainSmushGate.__array__(self, dtype)
#     146 def __array__(self, dtype=None):
# --> 147     self._array = ConversionGainSmush.construct_U(float(self.params[0]), float(self.params[1]), float(self.params[2]), float(self.params[3]), [float(el) for el in self.params[4:4+self.xy_len]], [float(el) for el in self.params[4+self.xy_len:-1]], t= float(self.params[-1]))
#     148     return self._array
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/hamiltonian.py:125, in ConversionGainSmush.construct_U(phi_c, phi_g, gc, gg, gxvector, gyvector, t)
#     123 totalUi = np.eye(4)
#     124 for it in range(N):
# --> 125     Ui = h_instance._construct_U_lambda(phi_c, phi_g, gc, gg, gxvector[it], gyvector[it])(timestep).full()
#     126     totalUi = Ui @ totalUi
#     127 return totalUi
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/hamiltonian.py:24, in Hamiltonian._construct_U_lambda.<locals>.<lambda>(t)
#      23 def _construct_U_lambda(self, *args):
# ---> 24     return lambda t: (-1j * t * self._construct_H(*args)).expm()
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qutip/qobj.py:1146, in Qobj.expm(self, method)
#    1143     raise TypeError('Invalid operand for matrix exponential')
#    1145 if method == 'dense':
# -> 1146     F = sp_expm(self.data, sparse=False)
#    1148 elif method == 'sparse':
#    1149     F = sp_expm(self.data, sparse=True)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/qutip/sparse.py:400, in sp_expm(A, sparse)
#     398 else:
#     399     E = spla.expm(A.toarray())
# --> 400 return sp.csr_matrix(E)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/sparse/_compressed.py:85, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      81     except Exception as e:
#      82         raise ValueError("unrecognized {}_matrix constructor usage"
#      83                          "".format(self.format)) from e
#      84     self._set_self(self.__class__(
# ---> 85         self._coo_container(arg1, dtype=dtype)
#      86     ))
#      88 # Read matrix dimensions given, if any
#      89 if shape is not None:
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/scipy/sparse/_coo.py:178, in coo_matrix.__init__(self, arg1, shape, dtype, copy)
#     175     self.has_canonical_format = False
#     176 else:
#     177     #dense argument
# --> 178     M = np.atleast_2d(np.asarray(arg1))
#     180     if M.ndim != 2:
#     181         raise TypeError('expected dimension <= 2 array or matrix')
#
# File <__array_function__ internals>:180, in atleast_2d(*args, **kwargs)
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/numpy/core/shape_base.py:81, in atleast_2d(*arys)
#      77 def _atleast_2d_dispatcher(*arys):
#      78     return arys
# ---> 81 @array_function_dispatch(_atleast_2d_dispatcher)
#      82 def atleast_2d(*arys):
#      83     """
#      84     View inputs as arrays with at least two dimensions.
#      85
#    (...)
#     117
#     118     """
#     119     res = []
#
# KeyboardInterrupt:

# %%
from src.utils.visualize import coordinate_2dlist_weyl
fig = coordinate_2dlist_weyl(ret3[1], c=range(len(ret3[1])));
# add onto figure segment from B to sqswap
ax = fig.gca()
ax.plot([.5,.75], [.25, .25], [0, .25], 'k--');
ax.plot([.5,.25], [.25, .25], [0, .25], 'k--');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from src.utils.visualize import coordinate_2dlist_weyl
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> fig = coordinate_2dlist_weyl(ret3[1], c=range(len(ret3[1])));
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # add onto figure segment from B to sqswap
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224f707469706c6578227d/home/evm9/decomposition_EM/src/scripts/gate_exploration/line_segment.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> ax = fig.gca()
#
# File ~/decomposition_EM/src/scripts/gate_exploration/../../../src/utils/visualize.py:145, in coordinate_2dlist_weyl(*coordinate_list, **kwargs)
#     143         sp = w.scatter(*zip(*inner_list), c=col, **kwargs)
#     144     else:
# --> 145         sp = axs.scatter3D(*zip(*inner_list), **kwargs)
#     146 w.render(axs)
#     147 if 'c' in kwargs:
#
# File ~/decomposition_EM/decomp_venv/lib/python3.8/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# TypeError: scatter() got multiple values for argument 'c'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# _ret3 = optimizer3.approximate_target_U(s)
basis.build(_ret3.cycles)
circuit =basis.assign_Xk(_ret3.Xk)
print("Cost:", basis.circuit_cost(Xk=_ret3.Xk))
circuit.draw(output='mpl');
# Out:
# Cost: 1.5740792009946547
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

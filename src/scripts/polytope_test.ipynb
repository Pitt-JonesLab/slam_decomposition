# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

import sys
sys.path.append("../../")

# %matplotlib widget

# %%
from src.basis import CircuitTemplate
basis = CircuitTemplate(preseed=False, use_polytopes=True)

# %%
from src.cost_function import BasicCost
objective = BasicCost()

# %%
from src.optimizer import TemplateOptimizer
optimizer = TemplateOptimizer(basis=basis, objective=objective, use_callback=True)

# %%
from src.sampler import Haar3Sample as HaarSample
sampler = HaarSample(n_samples=5)
ret = optimizer.approximate_from_distribution(sampler=sampler)
# Out:
# WARNING:root:This sampler only works for \sqrt[2]iSwap
# INFO:root:Starting sample iter 0
# INFO:root:Begin search: (0.67851193, 0.22370781, 0.10692813)
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=5.0362236603263e-10
# INFO:root:Success: (0.67851193, 0.22370781, 0.10692813)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 1
# INFO:root:Begin search: (0.60757565, 0.36742577, 0.02897262)
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=2.331076442985136e-10
# INFO:root:Success: (0.60757565, 0.36742577, 0.02897262)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 2
# INFO:root:Begin search: (0.5359893, 0.26074396, 0.21044897)
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=4.670863695821481e-11
# INFO:root:Success: (0.5359893, 0.26074396, 0.21044897)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 3
# INFO:root:Begin search: (0.41782701, 0.34713017, 0.27217252)
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=8.147726937579591e-11
# INFO:root:Success: (0.41782701, 0.34713017, 0.27217252)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 4
# INFO:root:Begin search: (0.5180464, 0.37119007, 0.14334693)
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=8.600720136087148e-11
# INFO:root:Success: (0.5180464, 0.37119007, 0.14334693)
# INFO:root:Saving data back to file

# %%
from src.utils.visualize import optimizer_training_plot
optimizer_training_plot(*ret)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

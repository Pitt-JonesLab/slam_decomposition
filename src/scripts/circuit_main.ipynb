# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

import sys
sys.path.append("../../")

# %matplotlib widget

# %%
from src.basis import CircuitTemplate
basis = CircuitTemplate(maximum_span_guess=4, preseed=False)

# %%
from src.cost_function import BasicCost
objective = BasicCost()

# %%
from src.optimizer import TemplateOptimizer
optimizer = TemplateOptimizer(basis=basis, objective=objective, use_callback=True)

# %%
from src.sampler import Haar3Sample as HaarSample
sampler = HaarSample(n_samples=5)
ret = optimizer.approximate_from_distribution(sampler=sampler)
# Out:
# WARNING:root:This sampler only works for \sqrt[2]iSwap
# INFO:root:Starting sample iter 0
# INFO:root:Begin search: (0.44521934, 0.33134635, 0.15468071)
# INFO:root:Starting opt on template size 1
# INFO:root:Starting opt on template size 2
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=6.127933716015832e-10
# INFO:root:Success: (0.44521934, 0.33134635, 0.15468071)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 1
# INFO:root:Begin search: (0.33688237, 0.29758088, 0.17801476)
# INFO:root:Starting opt on template size 1
# INFO:root:Starting opt on template size 2
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=6.896417881208095e-10
# INFO:root:Success: (0.33688237, 0.29758088, 0.17801476)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 2
# INFO:root:Begin search: (0.61249902, 0.3028133, 0.08782785)
# INFO:root:Starting opt on template size 1
# INFO:root:Starting opt on template size 2
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=2.304787471985037e-10
# INFO:root:Success: (0.61249902, 0.3028133, 0.08782785)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 3
# INFO:root:Begin search: (0.42029334, 0.33424416, 0.22948806)
# INFO:root:Starting opt on template size 1
# INFO:root:Starting opt on template size 2
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=4.8132942076506424e-11
# INFO:root:Success: (0.42029334, 0.33424416, 0.22948806)
# INFO:root:Saving data back to file
# INFO:root:Starting sample iter 4
# INFO:root:Begin search: (0.45355919, 0.34737136, 0.12914014)
# INFO:root:Starting opt on template size 1
# INFO:root:Starting opt on template size 2
# INFO:root:Starting opt on template size 3
# INFO:root:Break on cycle 3
# INFO:root:Loss=4.97088481488106e-10
# INFO:root:Success: (0.45355919, 0.34737136, 0.12914014)
# INFO:root:Saving data back to file

# %%
from src.utils.visualize import optimizer_training_plot
optimizer_training_plot(*ret)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

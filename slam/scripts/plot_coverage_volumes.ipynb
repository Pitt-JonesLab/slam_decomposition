# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %matplotlib widget
import numpy as np
from slam.utils.polytopes.coverage_plot import plot_coverage_set
from slam.basis import MixedOrderBasisCircuitTemplate
from slam.utils.gates.custom_gates import ConversionGainGate

# %%
# #coverage of an arbitrary gate 
# # will load coverage polytope from file in template constructor or create it if it doesn't exist
# base_gate = ConversionGainGate(0,0, np.pi/8, 3*np.pi/8, 1/2)
# template = MixedOrderBasisCircuitTemplate(base_gates=[base_gate], chatty_build=0, bare_cost=True)
# plot_coverage_set(template.coverage[:], save=0, filename=f"coverage_set_custom")

# %%
iswap = np.pi/2, 0, 1, "iSwap", 3
sqiswap = np.pi/2, 0, 1/2, "sqiSwap", 3
cnot = np.pi/4, np.pi/4, 1, "CNOT", 3
sqcnot = np.pi/4, np.pi/4, 1/2, "sqCNOT", 6
b = 3*np.pi/8, np.pi/8, 1, "B", 2
sqb = 3*np.pi/8, np.pi/8, 1/2,  "sqB", 4
gate_list = [iswap, sqiswap, cnot, sqcnot, b, sqb]

# %%
use_smush = 1
for gate_prop in gate_list[1:2]:
    base_gate = ConversionGainGate(0,0, *gate_prop[:3])
    template = MixedOrderBasisCircuitTemplate(base_gates=[base_gate], chatty_build=0, bare_cost=True, use_smush_polytope=use_smush)
    fname = f"coverage_set_{gate_prop[3]}"
    if use_smush:
        fname += "_smush"

    poly_list = template.coverage
    plot_coverage_set(poly_list[:], save=1, filename=fname)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       7     fname += "_smush"
#       9 poly_list = template.coverage
# ---> 10 plot_coverage_set(poly_list[:], save=1, filename=fname)
#
# File ~/slam_decomposition/slam/utils/polytopes/coverage_plot.py:24, in plot_coverage_set(coverage_set, save, filename, **kwargs)
#      19 for k, circuit_polytope in enumerate(
#      20     coverage_set[1:][::-1]
#      21 ):  # reversed so inner polytopes are on top
#      22     # recalc the index becuase of the reversed order
#      23     index = len(coverage_set[1:]) - k - 1
# ---> 24     fig = _plot_circuit_polytope(
#      25         circuit_polytope, fig=fig, index=index, save=False
#      26     )  # , override_connect=index in kwargs.get("override_connect_indices", []))
#      27 if save and filename is not None:
#      28     plt.savefig(f"{fpath_images}/{filename}.pdf", format="pdf")
#
# File ~/slam_decomposition/slam/utils/polytopes/coverage_plot.py:100, in _plot_circuit_polytope(circuit_poly, fig, index, save, filename, override_connect)
#      98     w.render(ax)
#      99 else:
# --> 100     ax = fig.gca(projection="3d")
#     102 color = [
#     103     "red",
#     104     "green",
#    (...)
#     112     "grey",
#     113 ][index % 10]
#     114 reduced_vertices = (
#     115     monodromy_to_positive_canonical_polytope(circuit_poly).reduce().vertices
#     116 )
#
# TypeError: FigureBase.gca() got an unexpected keyword argument 'projection'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
